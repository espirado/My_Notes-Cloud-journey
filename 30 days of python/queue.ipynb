# %%
from collection import deque

class queue:
    def __init__(self):
    self.buffer = deque()

    def enqueue(self,value):
        self.buffer.appendleft(value)

    def dequeue(self):
        if len(self.buffer) == 0:
            print("queue is empty")
            return 
         return self.buffer.pop()
    def size(self):
        return len(self.buffer) 

    def isempty(self):
        return len(self.buffer) == 0

   food_order = queue

   def place_orders(orders):
       for order in orders:
           print("placing order for ":,order)
           food_order_queue.enqueue(order)
           time.sleep(0.5)

def serve_orders():
    time.sleep(1)
    while True:
        order = food_order_queue.dequeue()
        print("Now serving",order)
        time.sleep(o.5)
if __name__ == '__main__':
    orders = ['pizza','samosa','pasta','biryani','burger']
    t1 = threading.Thread(target=place_orders, args=(orders,))
    t2 = threading.Thread(target=serve_orders)

    t1.start()
    t2.start()

# %%
from collections import deque 
import uuid 
from datetime import datetime 


class queue:
    def __init__(self):
        self.queue = deque()


    def enqueue(self, item):
        self.enqueue.append(item)
        print(f"Enquered: {item}")

    def dequeue(self):
        if self.is_empty():
            return "queue is empty"
            item = self.queue.popleft()
            print(f"dequeue: {item}")
    def is_empty():
        return len(self.queue) ==0 

    def size(self):
        return len(slef.queue)

    def peek(self):
        if self.isempty():
            return "queue is empty"
        return self.queue[0]

   def display(self):
       print(f"Queue: {list(self.queue)}")


Class orderingTicket():
    def __init__(self):
        self.tickets = {}
        self.ticket_queue = Queue()


    def create_tickets(self,customer_id, request_details):
        ticket_id = str(uuid.uuid4())
        timestamp = datetime.now()strftime("%Y-%m-%d %H:%M:%S")
        ticket_info = {
            "ticket_id": ticket_id,
            "customer_id": customer_id,
            "request_details": request_details,
            "timestamp": timestamp,
            "status": "open"
        
        }
        self.tickets[ticket_id] = ticket_info
        self.ticket_queue.enqueue(ticket_id)
        return ticket_id

    def serve_ticket(self):
        if self.ticket_queue.is_empty():
            return "No tickets to serve"
        
        ticket_id = self.ticket_queue.dequeue()
        if ticket_id in self.tickets:
            self.tickets[ticket_id]["status"] = "served"
            return self.tickets[ticket_id]
        return "Ticket not found"

    def get_ticket(self, ticket_id):
        return self.tickets.get(ticket_id, "Ticket not found")

    def list_tickets(self, customer_id=None):
        if customer_id:
            return {tid: details for tid, details in self.tickets.items() if details["customer_id"] == customer_id}
        return self.tickets

# Example Usage
if __name__ == '__main__':
    system = TicketOrderingSystem()
# Out:
#   File <string>:31
#     def display(self):
#                       ^
# IndentationError: unindent does not match any outer indentation level
